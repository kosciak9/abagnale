# %%
import pandas as pd

# %%
iosco = pd.read_html('./sources/iosco.html')[0]
iosco
# Out:
#                                                Company  \
# 0                                 COOPER MARKETS s.r.o
# 1                               Zurich Markets Limited
# 2                               Inquot Investing Group
# 3                                          iAlphagroup
# 4    Novak Peter Financial Advisors & Solutions (Cl...
# ..                                                 ...
# 477                                     Fast Easy Cash
# 478                         Credit Finance Corporation
# 479                                       MCManagement
# 480          FR Investments/First Response Investments
# 481                                          Bond Guru
#
#                                         Regulator    Jurisdiction  \
# 0                             Czech National Bank  Czech Republic
# 1    Swiss Financial Market Supervisory Authority     Switzerland
# 2    Swiss Financial Market Supervisory Authority     Switzerland
# ...

# %%
iosco.to_csv('outputs/iosco.csv')
