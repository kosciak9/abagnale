# %%
import scraper

# %%
web = scraper.Web.from_url('https://www.zurichmarkets.com/', depth=2)
web
# Out:
# ...
# Web with 32 sites

# %%
web['https://www.zurichmarkets.com/account-types/']
# Out:
# Site at https://www.zurichmarkets.com/account-types/ with 30 links

# %%
web['https://www.zurichmarkets.com/account-types/'].soup.body
# Out:
# <body class="page-template-default page page-id-300 mega-menu-primary">
# <script type="text/javascript">
# jQuery(document).ready(function(){
# 	// Open menu box if customer are logged on web
# 	jQuery('#toggleMenuAction').on("click",function(){
# 		jQuery('.menuBoxOpen').toggle();
# 	});
#
# // Open menu box if customer are logged on mobile
# 	jQuery('#toggleMenuActionMobile').on("click",function(){
# 			jQuery('.menuBoxOpen').toggle();
# 	});
#
# });
#
# </script>
# <header class="site-header" style="background-color:#30303000;">
# <section class="info-center-container desktop" style="display: block; height: 37.8px; padding-top: 0px; margin-top: 0px; padding-bottom: 0px; margin-bottom: 0px;">
# <div class="container" style=" padding: 0px; ">
# <div class="row" style="padding-top:0px;padding-bottom:0px">
# <div class="floatright lemp" style="float: right;text-align: right;width: auto;">
# <div class="pull-right none-float">
# <div style="display: none;">
# ...
