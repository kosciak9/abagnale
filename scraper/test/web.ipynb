# %%
import scraper

# %%
web = scraper.Web.from_url('https://www.finma.ch/en/finma-public/warning-list/zurich-markets-limited/', depth=2, verbose=True)
web
# Out:
# Fetching https://www.finma.ch/en/finma-public/warning-list/zurich-markets-limited/
# Fetching https://www.finma.ch/en/finma-public/financial-literacy/
# Fetching https://www.finma.ch/en/supervision/asset-management/
# Fetching http://www.admin.ch/opc/en/classified-compilation/20052624/index.html
# Fetching https://www.finma.ch/en/finma/organisation/
# Fetching https://www.finma.ch/en/supervision/fintech/
# Fetching https://www.finma.ch/en/documentation/dossier/
# Fetching https://www.finma.ch/en/supervision/self-regulatory-organisations-sros/
# Fetching https://www.finma.ch/en/documentation/self-regulation/
# Fetching https://www.finma.ch/en/authorisation/rating-agencies/
# Fetching https://www.finma.ch/en/supervision/cross-sector-issues/
# Fetching https://www.finma.ch/en/finma-public/warning-list/
# Fetching https://www.finma.ch/en/finma-public/
# Fetching https://www.finma.ch/en/documentation/selected-rulings/
# Fetching https://portal.finma.ch/auth-login/portal?lang=en
# ...

# %%
for site in web.sites:
    print(site)
# Out:
# Site at https://www.finma.ch/en/documentation/legal-basis/ with 103 links
# Site at https://www.finma.ch/en/impressum/ with 96 links
# Site at https://www.finma.ch/en/news/ with 99 links
# Site at https://www.finma.ch/en/personal-download-list/ with 96 links
# Site at https://www.finma.ch/en/enforcement/all-about-enforcement/ with 131 links
# Site at https://www.finma.ch/en/finma/supervisory-objectives/ with 110 links
# Site at https://www.finma.ch/en/authorisation/institutions-and-products-subject-to-the-collective-investment-schemes-act/ with 116 links
# Site at https://www.finma.ch/en/documentation/circulars/ with 110 links
# Site at https://www.finma.ch/en/~/media/finma/dokumente/dokumentencenter/myfinma/6finmapublic/finma-ein-portraet.pdf with 0 links
# Site at https://www.finma.ch/en/supervision/financial-market-infrastructures/ with 107 links
# Site at https://www.finma.ch/en/finma/finma-an-overview/ with 109 links
# ...
