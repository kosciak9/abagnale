# %%
import spacy
import re
from tqdm.auto import tqdm
from scraper import Web, Site

# %%
nlp = spacy.load('en_core_web_lg') # if this doesn't work, run spacy download en_core_web_lg

# %% [markdown]
# # Experiments

# %%
eg_site = Site.from_url('https://www.zurichmarkets.com/')
eg_site
# Out:
# Site at https://www.zurichmarkets.com/ with 30 links

# %%
eg_text = eg_site.soup.body.get_text()
'Zurich Markets' in eg_text
# Out:
# True

# %%
doc = nlp(eg_text)
set(ent.label_ for ent in doc.ents)
# Out:
# {'CARDINAL',
#  'DATE',
#  'GPE',
#  'LANGUAGE',
#  'NORP',
#  'ORG',
#  'PRODUCT',
#  'WORK_OF_ART'}

# %%
set(ent.text.strip() for ent in doc.ents if ent.label_ == 'ORG')
# Out:
# {'AML PolicyFunding MethodsBonus Offerings',
#  'Android Trader',
#  'CFD',
#  'CryptoEducation',
#  'FX',
#  'Ipad Trader',
#  'Iphone Trader',
#  'Login',
#  'Lowest',
#  "More.- World's",
#  'PolicyTerm & ConditionsDeposit Policy',
#  'TraderAndroid TraderiPhone Trader',
#  'UsWhy',
#  'Zurich Markets',
#  'Zurich Markets Limited',
#  'Zurich Markets Web & Mobile Platforms',
#  'Zurich Markets’s',
#  'the Zurich Markets Trading Specialist-'}

# %%
set(ent.text.strip() for ent in doc.ents if ent.label_ == 'PERSON')
# Out:
# set()

# %%
set(ent.text.strip() for ent in doc.ents if ent.label_ == 'PRODUCT')
# Out:
# {'Crypto', 'Explorer', 'MT4'}

# %%
set(ent.text.strip() for ent in doc.ents if ent.label_ == 'LANGUAGE')
# Out:
# {'English'}

# %%
'Support@zurichmarkets.com' in eg_text
# Out:
# True

# %%
re.findall(r'[\w\.-]+@[\w\.-]+', eg_text)

# %% [markdown]
# # Actual thing

# %%
web = Web.from_zip('./outputs/iosco.gz')
web
# Out:
# Web with 2605 sites

# %%
interesting_sites = [site for site in tqdm(web) if site.soup.body is not None]
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2605.0), HTML(value='')))

# %%
interesting_labels = ['PERSON', 'PRODUCT', 'ORG']
set(
    ent.text
    for site in tqdm(interesting_sites)
    for ent in nlp(site.soup.body.get_text()).ents
    if ent.label_ in interesting_labels
)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2436.0), HTML(value='')))
# {'Kuvera France',
#  'est conçu pour vous permettre de profiter de tous vos',
#  'Fundación Universitaria San Pablo',
#  'SvenskaSV',
#  'Handeln Sie mit',
#  'practicar\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLo que',
#  'Golden Water Ventures Ltd',
#  'White Rock Partners Ltd',
#  'Mobile Money Ltd',
#  'załatwianie sprawPowrótSposoby przyjmowania',
#  'para invertir',
#  'Financial and Consumer Affairs Authority of Saskatchewan',
#  'Dlaczego',
#  'przewidziane są specjalne bonusy',
#  'bardzo dobrze',
#  'das Münchner',
#  'Zdraví\n\n\n\n\n\n\n\n\n\n',
#  'Metale\n\n\n\n\n\n',
#  'protéger contre les arnaquesSe préparer à',
#  'mi się strona',
#  'dado o de cualquier manera',
#  'Platformę Transakcyjną',
#  'Zweigniederlassung Frankfurt am Main',
#  'przekonaniem stwierdzić',
#  'Zostań Partnerem',
#  'Platinum Cfd',
#  'że na rachunku znajdują się wystarczające środki',
#  'Latitude Investment Management Llp',
#  'Gordan Ramsey',
#  'Normativa',
#  'Życzę InstaForex dalszego',
#  'KomisjaSkład KomisjiZadania KomisjiDziennik',
#  'GEGEN DIE',
#  'Indices\n\n\nTrade',
#  'Regulamin  |',
#  '3300\n\n\n\t\t\t\t\t\t\t\t',
#  'Corporate & Institutional Solutions',
#  'Ако имате',
#  'Butler Westbury Limited (Trading',
#  'Aleksander Minsyk',
#  'sur mesure selon la stratégie d’investissement prédéfinie et votre appétence au',
#  'Collèges',
#  'processJob VacanciesSome',
#  'sur les navigateurs que nous supportons',
#  'ustanawia z każdym z',
#  'DirectUsługi',
#  'que nunca duermen',
#  'su éxito',
#  'Bleaxmond / Alephlink Solutions Limited - Bullishcoin / BS Creative Management - Credit Suisse Ag / Csif',
#  'działać jako mediator',
#  'IMT Technologies',
#  'Cela signifie que chaque fois que vous visiterez ce',
#  'UnderstandingInternational OrganisationsInternational SanctionsSanctions',
#  'Colégio EMIR',
#  'Donaldson-Finley Corporate Partners',
#  'welche unserer Seiten Sie besucht haben',
#  '730b',
#  'Gospodarka Federacji Rosyjskiej',
#  'une vision globale du système',
#  'Leistungen zur Seite zu stehen',
#  'comptables internationales',
#  'relación con lo establecido en',
#  'the EIOPA Consultation Paper',
#  'kliencie wymaganych',
#  'Yale University',
#  "ResolutionDocuments de réflexion de l'ACPREurope et international                                                                                              ",
#  'Kraj',
#  'Título Habilitación del título Fecha de incorporación',
#  'Hangtung International Wealth',
#  'FINMA mandataries',
#  'także ogólne informacje',
#  'Ritorma Sp.',
#  'która dostarcza lub rzekomo',
#  'już na podobnej',
#  'że wszystkie zlecenia handlowe',
#  'Privatiers',
#  'regula las condiciones de autorización y funcionamiento de las Empresas de Servicios de Inversión',
#  'rischi',
#  'souhrn07/31/2020 - Newsletter',
#  'Robert Paszkowski',
#  'U-Nex Ltd',
#  'loro esclusiva discrezione e',
#  'Publicaciones y otros contenidos\n\n\n\n\n',
#  'Parker',
#  'WIR UNSEREN',
#  'Market News',
#  'El propio Trump',
#  'Bayreuther Str',
#  'QuébecBibliothèque Marie-VictorinRevenu QuébecOrdre des CPA du QuébecBibliothèque et Archives',
#  'Viele Datenverarbeitungsvorgänge',
#  'KOMENTÁŘ -',
#  'customerservice@advfinance.uk\n\n\n\n\n\n\n\n\n\n',
#  'się opinią',
#  'EFP',
#  'Dla Traderów',
#  'M&G plc',
#  'Abonnement Publications',
#  'Siria',
#  'Heron Wealth Management Limited',
#  'Facebook3',
#  'Mathematics and Statistics',
#  'protéger contre les arnaques',
#  'Platin Cfd',
#  'IP-Adressen',
#  'WilliamPartners',
#  'Titularização de créditos\n\n\n',
#  '简体中文\n\n\n\n\n',
#  'Sebastian Toczek',
#  'Capitals',
#  'Mary Holm',
#  'Pariba Group',
#  'podczas publikacji informacyjnych',
#  'Depaho Ltd',
#  'Transakcji została osiągnięta',
#  'Access Sandbox',
#  'Analistas de forex',
#  'Equalizer Ltd',
#  'Política\xa0de\xa0',
#  'Jego kompetentne kursy pomogły mi opanować tajniki handlu',
#  '@CNMV_IFI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n',
#  'cualquier pérdida de ganancias',
#  'StockGifts',
#  'Гласувай',
#  'Ifp Markets',
#  'IP-Adresse',
#  'Doskonała obsługa',
#  'Alternative Investment Fund Management',
#  'em que',
#  'First Class Financial Group',
#  'Customs',
#  'Klienta Spółka',
#  'bardzo ekscytujące',
#  'Sint Eustatius',
#  'the Estonian Financial Intelligence Unit',
#  'numer trasy',
#  'NSI',
#  'NB',
#  'Pośrednictwo Finansowe Krzysztof Poniatowski',
#  'CFD Trader\n\n\n\n',
#  'KOMENTÁŘ - Marek Mora k',
#  'Retrouvez-nous sur',
#  'deberán presentar',
#  'Marco regulatorio',
#  'English14 February 2020Notification',
#  'pero',
#  'Справки',
#  'zu können',
#  'Biełow Igor Wiaczesławowicz',
#  'investteck TLD Extension',
#  'Bankenaufsicht',
#  'Warszawa-Mokotów',
#  'Kontaktdaten zur Übersendung von nicht ausdrücklich',
#  'Zawsze aktualne',
#  'Obtenga acceso',
#  'Fed',
#  'solidnym brokerem',
#  'Â£2,000\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n',
#  'análise financeira ou',
#  'Bwb Ireland Investment Management / B.W.B.',
#  'Contacto',
#  'Prabhune',
#  'Windows & MT4',
#  'Article 171(1–3',
#  'Fidex Market',
#  'Nous utilisons des cookies pour améliorer votre expérience de navigation sur notre',
#  'Forbidden\r\n\nAccess',
#  'Lengvin Partners Ltd',
#  'Arbitraje de cambio \n\n ',
#  'planea invertir casi',
#  'Federal Trade Comission',
#  'de modo que la autenticidad de las condiciones y el volumen de operaciones de Quantfury',
#  'KRS 416276',
#  'prowadzenie działalności',
#  'Acceso',
#  'Fintech ACPR',
#  'Pour répondre à ces objectifs',
#  'www.tycoon69int.com',
#  'Forge Global',
#  'GovernorsExecutive',
#  'démarchesÊtes-vous en union libre',
#  'Bond Compare - Solar Claim Experts - National',
#  'Intercontinental Cup Winners',
#  'badania ryzyka',
#  'First Financial Banc',
#  'Produkten auf',
#  'the Information Commissioners Office',
#  'Boogie Boards, & SUP Boards',
#  'Generando Ganancias',
#  'filles le matinDes communautés',
#  'Hammer',
#  'Macquarie Capital (Europe) Limited',
#  'Germany\n        \n        \n      \n\n',
#  'Nebezpečné výrobky',
#  'unseres Hauses',
#  'Inversión',
#  'Contact us\n\n\n\n',
#  'Harriet Lefton',
#  '2020Forget Black Friday Deals',
#  'Klienta jest zapoznanie się',
#  'La carte verte devient blanche',
#  'Nomos Wealth Management',
#  'MT4 para',
#  'Jestem',
#  'Allay Claims Ltd',
#  'Credit Institution Branches (European Union',
#  'принять участие',
#  'Antes de negociar cualquier clase de activos',
#  'GEMI',
#  'de garantie et',
#  'BondComparison -',
#  'Success',
#  'NorthfintechFX Trading Services Ltd',
#  'de FranceBankProdémialKonsultant',
#  'wiadomości,',
#  'Adobe',
#  'de crédits Crédit à la',
#  'Stavros',
#  'dans toute la',
#  'das Hinweisgebersystem',
#  'Ubrokers',
#  'quelles sont les règles',
#  'es necesario descargar o',
#  'der Business Keeper AG',
#  'Kreditservices\n\n\n\n\n',
#  'la autoridad competente correspondiente de que recurren',
#  'Novidades',
#  'opciones sobre acciones',
#  'CEAFP',
#  'Interessen überwiegen',
#  'Mapa\n\n\n',
#  'American Securities - 247 Options Trade - 1st',
#  'Gdańsk',
#  'BTM',
#  'Slovakia Central Bank',
#  'the BC Securities Commission',
#  'CZY',
#  'narzędzi bez ryzyka',
#  'Декларация',
#  'Twitter\n\n\n\n\n\n\n\n\n\n\n\n',
#  'Toggle',
#  'que lo ayudan',
#  'Klienta ze',
#  'Interfox Commercial Limited',
#  'Cryptoasset',
#  'Redfin Capital - Hunterlyinvest - Sky Line/ Skylinevest.com - Best Investment Bonds',
#  'protette contro',
#  'Česká národní banka na FacebookuZaloguj',
#  'kontaktujte Å¡Ã©fredaktora',
#  'Unikalna',
#  'Maggie Fitzgerald',
#  'Dariusz Cyganek',
#  'First Financial Banc / Warp Enterprise Ltd - Multifx Signals Limited - Fxlifestyle - www.facebook.com/2circlefx/\n\n      ',
#  'se hace',
#  'navigation',
#  'the European Parliament',
#  'M. BelfastProfit',
#  'Kingsbridge Capital Advisors Limited',
#  'WishlistInstallThe Spanish National Securities Market Commission',
#  'de livre prestação de serviços',
#  'uso ambas',
#  'zespołowi nauczycieli InstaForex',
#  'občana262Marek Mora k případu Spolkový',
#  'Future\xa0',
#  'Vous pouvez également',
#  'Swiss Financial Market\n\n      Supervisory Authority',
#  'otwierania zleceń',
#  'że czasem',
#  'kontoNie',
#  'Szymon M.',
#  'Sie Ihren Hinweis',
#  'DNS',
#  'za jakiekolwiek',
#  'Sao Tome',
#  'otwarcia rzeczywistego',
#  'können wir diese Wünsche selbstverständlich berücksichtigen',
#  'Telefónica',
#  'companyLfg Kronos Investment Services Gmbh / Lfg Value Investment Services GmbH',
#  'MEC',
#  'the Prosecutor of Regional Prosecutor’s',
#  'www.schwab.uk.com',
#  'un promedio de 101 puntos',
#  'Conquista los mercados',
#  'Jared Hartstein',
#  'À quoi',
#  "AG-Markets'",
#  'Ihre Meldung wird',
#  'los mercados de valores',
#  'że poziom',
#  'Bond Advisory',
#  'Wize Capital',
#  'traitement informatique destiné à l’AMF pour effectuer le suivi des dépôts',
#  'Stop - przyszłe zlecenie Kupna',
#  'Independent Wealth Brokers',
#  'bro\x8d\r\n',
#  '© Plan de Educación Financiera',
#  'Amount\n',
#  'NT8',
#  'Organisation beschäftigt sind und',
#  'Sunset Premium Investment Ltd',
#  'Si avvisa',
#  'Btc - Forte-Miners',
#  "dans cette rubrique tout ce que vous devez savoir sur les produits d'assurance",
#  'Boletin informativo',
#  'PAMM System',
#  'interactivos',
#  'Amazon',
#  'Moneycorp',
#  'Patrimónios - Sociedade Gestora de Patrimónios',
#  'AG Markets',
#  'DRSP',
#  'Register now\n\n\n\n\n\n\n\n\n',
#  '微信公众号\n\n\n\n\n',
#  'BUDSFX',
#  'unterscheidet sich von anderen Anlageklassen',
#  'Fx-globalinvest Ltd',
#  'Russian)Svenska',
#  'Hinweise mittels zertifizierter',
#  'Opcje wyświetlania reklam',
#  'o każdej usłudze',
#  'Quantum Trading',
#  'European Payments',
#  'Marketscfd / Swissgems Ltd',
#  'wskazanym czasie',
#  'kont\n\n\n\n\n',
#  'Sie können eine bereits',
#  'finanzas para todos',
#  'asociándonos con empresas',
#  'A THIRD PARTY',
#  '版权与免责声明',
#  'de todo el mundo',
#  'rzeczywiste zostało otworzone',
#  'Financial Conduct Authority - FCA',
#  'BasicsWhat',
#  'gdy przyznano',
#  'przez Klienta może',
#  'zlecenie limitowe',
#  'Italiano\n                            \n\n ',
#  'dias\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n',
#  'Crown Compare',
#  'oraz ważny',
#  'PumaBroker',
#  'Acciones de supervisión',
#  'X-Clearing Corporation',
#  'es greift auf keine Ihrer',
#  'Aktien zu handeln',
#  'skutecznej pracy',
#  'istnieją ulgi oraz',
#  'Shoot',
#  'Consulter ABE-InfoService',
#  'más que nunca',
#  'Tribely',
#  'Ben G\n\n\n',
#  'że nie ma',
#  'the Position\nTrader',
#  'Board of Appeal          \n\n\n\n        Management Board          \n\n\n\n        Joint Committee          \n\n\n\n        ',
#  'MCManagement',
#  'Twitter\n\n\n\n\n\n\n            ',
#  'Universidad Nacional de Educación',
#  'Petrakovs',
#  'Valia Trade LP',
#  'Lea y asegúrese de comprender completamente nuestros Términos',
#  'indeksami',
#  'Conoce más de nosotros\n\n\n\n\n\n\n\n\n\n\n\n\n\n',
#  'Meritkapital',
#  'Ainsi que sur les matières premières',
#  'Klienta z Usług',
#  'Login\n\n\n\n\n',
#  'NAI - Notificación de Actividad de Internalización',
#  'IOSCO Membership Map\n\n\n\n',
#  'Turnkey Forex',
#  'BIDU)',
#  'Колективни инвестиционни схеми',
#  'Zobacz',
#  'Prime Technologies LTD -\n\n      Royal Gates LTD / FxPrime - Krisimark Ltd - InterCryptos Ltd',
#  'BinaryOpt',
#  'Cruxinv',
#  'Solvabilité IISeuils de calcul des exigences',
#  '+\n\n\n\n',
#  'en garde contre de fausses',
#  "LCB-FTSignaler à l'ACPR un",
#  'Hongkong Yifu International Futures Limited',
#  'kilku sztuk ubrań',
#  'Menu\n\n\n\n\n\n',
#  'Jasna 24',
#  'Modalités de\r\n                  création de compte',
#  'rachunku Klienta',
#  'Prudential Distribution Limited',
#  'Aspen Holding',
#  'dass Sie uns diese mitteilen',
#  'Investment Banking and Financial Advisory',
#  'The Management Board',
#  'EIP',
#  'najważniejsze - zaufanie',
#  'kontrakty CFD',
#  'BKR4013',
#  'Aintree Finance Limited',
#  'gdy osiągnie pewien zysk',
#  'Administrative Penalty / Fine',
#  'rozpoczęcia handlu',
#  'Chemické \xa0\r\n\t\t\t\t\t\n\n\n\n',
#  'Rückschlüsse auf Ihre',
#  'roku byłam',
#  'Comisión Nacional del Mercado de Valores – CNMV',
#  'wygodne wpłacanie',
#  'Ganancias Deportivas',
#  'Fraktal Trader',
#  'że pomimo',
#  'el comercio con análisis exclusivos y',
#  'WEBTRADER\n\n\n\n\n\n\n',
#  'Comodo SSL \r\n          Security',
#  'La banque en temps réel\n\n\n\n\n\n',
#  'Finanzas para',
#  'Secura Bonds',
#  'KRS 313810',
#  'wyłącznej',
#  'Luxeeforex',
#  'Shavkal Alexander',
#  'Grandefex Soleil Rouge Inc',
#  'the 10th Appeal Criminal Division',
#  'Jacek K.',
#  'Sie eine Meldung abgeben',
#  'KRS 362080',
#  'RegistrationAdditional InformationRelated LinksHow',
#  'ogłoszenia makroekonomiczne',
#  'Seguridad de los fondos',
#  'client.marketsdock.com',
#  'zmieniłem około',
#  'Act',
#  'Kosmetika',
#  "-FTInstructions de l'ACPR en matière de LCB-FTLignes directrices",
#  'Contact\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n Toggle',
#  'Well Road House',
#  'Galp Gás Natural Distribuição\n        \n        \n      \n\n        \n          Allianz Capital Partners',
#  'www.primeinvest-fx24.com',
#  'Klientom lub publikować informacje rynkowe dotyczące konkretnego',
#  'auf Ihrem Rechner',
#  'Datenschutz auf einen Blick',
#  'FSM Smart Ltd',
#  'еврооблигациям',
#  'InvestTeck',
#  'długich lat udanej działalności',
#  'Infinity Loans / Chetwood Financial',
#  'AuditorThe Federal Audit Office',
#  'zrzeka się',
#  'SOMMES-NOUS',
#  'White Label\n\n\n',
#  'Junge Kunden\n',
#  'FrecuentesAliados ComercialesControle sus InversionesUtilice',
#  "the Client's Account",
#  'DMA',
#  'Mesa de ayuda',
#  'ErrorDocument',
#  'BitInvests',
#  'mají nižší',
#  'Pełnocennatelewizja Forex\n\n\n\n\n\n\n\n',
#  "Que se passe-t-il à la fin du contrat d'assurance",
#  'para comerciar como tal',
#  'W tym stosunkowo krótkim',
#  'CDF',
#  'pérdida de tiempo',
#  'GOOG)',
#  'Credit Suisse AG',
#  'rynku\n\n\n\n\n\n\n\n\n\n',
#  'der Risikoabsicherung von Währungen',
#  'Hinweise zu Beschwerden',
#  'Contact Us\n\n\n\n\n\n\n\n\n\n\n\n',
#  'au contrôle',
#  'welche Daten wir erheben',
#  'Telefon oder Telefax kontaktieren',
#  'CMS',
#  'usuwane lub dodawane przez',
#  'España\n\n\n',
#  'le soja',
#  'Dla mnie osobiście dobrze wykonana',
#  'Boogie Boards',
#  'gli individui',
#  'ProvidersRecognised PersonsCapital MarketsConduct SupervisionBankingInsuranceInvestmentsTrustees & Other FiduciariesCompany Service',
#  'connus sous le nom',
#  'SupervisionConsumer Information',
#  'Jamahiriya',
#  'Bankinter Gestión de Activos',
#  'сбережений',
#  'Ai Markets',
#  'Securitisation          \n\n\n\n\n\n\n\n\n\n        ',
#  'Prudential',
#  'Haut Conseil de stabilité financière',
#  'Moja',
#  'Conozca Más\n\n\n\nCripto',
#  'Sustainable',
#  'Zoe Jones',
#  'TradingDash TradingLitecoin TradingRipple TradingAccounts',
#  'Fx - Pepperstone Group Limited - Cibfx Limited - Ava Trade Ltd - Capitalia Limited /',
#  "Quelles sont les spécificités du contrat d'assurance",
#  'TotalRegistered \n\n\n\n',
#  'OrganizacjaOtwarte w',
#  'Ein lückenloser Schutz der Daten',
#  'Apera Asset Management',
#  'https://sparpiloten.ch',
#  'Donati Broker Sas',
#  'Contact\n\n\n\n\n\n\n',
#  'International Markets Live LTD',
#  'że gdy pojawiają się trudności',
#  'potwierdzenie SWIFT',
#  'Limited - Cosminvest S.A. /',
#  'Western Group Inc',
#  'www.virtualstocks.io',
#  'Publicações',
#  'independientemente de la clase de activo que opere el comercio',
#  'SD',
#  'Ukończyłem kurs szkoleniowy',
#  'BBLS',
#  'Buy/Sell',
#  'Nutzen Sie',
#  'Empezar',
#  'FINMA\n\n\n\n\n',
#  'Инвестирование в компании',
#  'Livret de développement durable et solidaire',
#  'Toot Capital S.L',
#  'Beste Chance',
#  'Reporte de datos sobre operaciones',
#  'Ferpay Ltd',
#  'Klient zainicjował zamknięcie',
#  'że konferencja odbywała się właśnie w Jekaterynburgu',
#  "gouvernement d'entreprise et le contrôle interne",
#  'the National Court Register',
#  'Vidéo',
#  'necesita monitorear sus Hoppers e interactuar básicamente',
#  'Quadriga Asset Management',
#  'oferuje bardzo dobre warunki',
#  'faire jouer',
#  'Leverage\nDeposit\xa0&\xa0Withdrawal',
#  'account!INVITE',
#  'Quicktradeoption',
#  'Invest And',
#  'gdy dane nie są zgodne z',
#  'Analiza wideo',
#  'Compatibility View Settings',
#  'Epargne Info Service',
#  'la corta en',
#  "budgetL'argent de pocheLes",
#  'se trate de una actividad auxiliar con respecto',
#  'Consultoria',
#  'Visa',
#  'Carte Bancaire',
#  'osiągnąć mi sukces',
#  'Securities\n\n      and Futures Commission - SFC',
#  'Empresas de servicios de inversión',
#  'Jordan Limited',
#  'Vaneda Partners Ltd',
#  'EC2M 4PL',
#  'wszystkiePostyUrząd Komisji Nadzoru',
#  'Wie läuft',
#  'Dział',
#  'Atlas Financial Ltd',
#  'Wspomniana',
#  'QUI SOMMES-NOUS',
#  'Currencies',
#  'avec effet',
#  'tritt auf',
#  'proprie spese',
#  'Login',
#  'также на управлении частными капиталами',
#  'Cloud VPS',
#  'de tal forma',
#  'Clear Media Ltd.',
#  'Privatkunden',
#  '精密零部件\n\n\n\n\n\n',
#  'Telegram2',
#  'CNMV\n          ',
#  'negociación de acciones e instrumentos',
#  'Wir unterstützen Sie',
#  'Przez te kilka miesięcy zdobyłem ogromną wiedzę',
#  'Platynowe Inwestycje SA',
#  'al equipo de 24invest',
#  'divisas',
#  'Warszawa-Śródmieście',
#  'Zam firmę od',
#  "un contrat d'assurance",
#  'eine gewöhnliche E-Mail-Kommunikation',
#  'NOVO BANCO',
#  'które firma zapewnia wszystkim',
#  'Public Relations Office',
#  'zostanie uruchomione zlecenie limitowe',
#  'EmailChrome',
#  'NIP 9271035268',
#  'sur le courtage en ligne',
#  'LLP',
#  'Board of Supervisors\n\nManagement Board',
#  'pratiquesCalculateursComparateur de comptes',
#  'Deutsche Bank AG',
#  'VerificationScan',
#  'Personenbezogene Daten und Informationen',
#  'przywileje',
#  'American Securities',
#  'Main Handelsregister',
#  'tuo sfavore',
#  'Klient zostanie obciążony prowizją Swap przez trzy',
#  'Zostań partnerem',
#  'qed joperaw',
#  'Kancelaria Twój Majątek',
#  'minusu',
#  'Perfect Money',
#  'dieser Datenschutzerklärung gesondert behandelt',
#  'Andars Lazo',
#  'los Clearing registrados',
#  'Bond-Supermarket',
#  'Cfd - Mm',
#  'Vivaexchange Oü',
#  'Seguirnos',
#  'TOOLSEarning',
#  'nas zdarza się sytuacja',
#  'Office for Professional Body Anti-Money Laundering Supervision',
#  'Tam znalazłem wiele ciekawych informacji',
#  'Yukon)\n\n\n\n\n\n\n\n\n\n\n',
#  'Comercio de papel',
#  'Insta Service Ltd',
#  'niech ten',
#  'ZA183098',
#  'dwar entità bl-isem ta',
#  'Joshua Consulting Ltd',
#  'Rückschlüsse auf',
#  'mhux konvenzjonali bħal',
#  'MFI',
#  'Ludzie',
#  'Login\n\n\n\n\n\n\n\n\n\n\n\nDigital',
#  'Facilitar el acceso de las pymes',
#  'StockKeep',
#  'Staram',
#  'Comprendre',
#  'WarningsForeign WarningsAdministrative Measures & PenaltiesEventsPublicationsMFSA',
#  'Securex Plus Solutions Eood',
#  'zamknięcia każdej transakcji',
#  'soit de vous inscrire à nos concours',
#  'un avenir commun\xa0\n',
#  'Spółce danych konta bankowego',
#  'który udostępnia informacje o sobie wszystkim zainteresowanym',
#  'więcej postów strony',
#  '大地资源',
#  'Partners - Farallon Capital LLC',
#  'различных секторах мировой экономики',
#  'Nuestras Tarifas',
#  'der FMA',
#  'Wrap',
#  'Violet Earl Asset Management Ltd',
#  'www.pillar-property-group.com',
#  'MIC',
#  'the Day Trader',
#  'wysokiej jakości analizy',
#  'Assurance garantie accidentAssurance',
#  'Android & iOS\n\n\nPartnership',
#  'Sioux Falls',
#  'Takie świadczenia mogą być',
#  'auch auf deren Qualität',
#  'Berichtigung oder Löschung dieser Daten zu verlangen',
#  'votre banquier ou votre intermédiaire',
#  'AUCH FÜR EIN AUF DIESE BESTIMMUNGEN GESTÜTZTES',
#  'Alior Bank SA',
#  'materiali chiave',
#  'които по договор непосредствено извършват',
#  'Faq',
#  'Consob',
#  'Distancia',
#  'ACCOUNT\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                ',
#  'Онлайн кредитование',
#  'Vous êtes une personne autorisée à déposer',
#  'widać',
#  'EGM Finance',
#  'II          \n\n\n\n\n\n\n\n\n\n        ',
#  'Käufer zögern',
#  'Globalinvestfx Ltd',
#  'platformie transakcyjnej',
#  'Google \n\n\n\n\n\n\n',
#  'Paweł J.',
#  'Warunki niniejszej Umowy',
#  'Eesti keelET',
#  'handelt sich nicht',
#  'Dawn l-entitajiet',
#  'Decálogo para',
#  'Lcoin Market',
#  'Środa Wielkopolska',
#  'específicos disponibles en la “ZONA',
#  'y lo recomiendo encarecidamente para el comercio diario',
#  'Usługi',
#  'Daten sowie ein Recht auf Datenübertragbarkeit',
#  'ISSUES?NO',
#  'Universal Markets /',
#  'Brookfield Public Securities Group',
#  'Reklama\n',
#  'DevTech Holding',
#  'Uk Bond Society',
#  'www.sbe-uk.com',
#  'und nutzen personenbezogene',
#  'INVESTIMENTO S.A.',
#  'Chcę podziękować wszystkim',
#  'Grand Marshall Ltd.',
#  'AJ Bell Asset Management Limited',
#  'о)Познай',
#  'Funds',
#  'Costs',
#  'JC Capital Ltd',
#  'Banco BIC Português',
#  'un crédit',
#  'Newsletter - Nº1825',
#  'las referencias',
#  'Tengo\xa0',
#  'Za',
#  'handlu\n\n\n\n',
#  'Fundación IDEC',
#  'PAYX',
#  'Die Einsichtnahme',
#  'hasło mają zastosowanie tylko dla platformy transakcyjnej',
#  'Us\n\n\n\n',
#  'klicken Sie oben auf',
#  'Arbeitsplatzes oder des Orts des',
#  'MMP Financial Limited (Trading',
#  'Duży wybór instrumentów finansowych',
#  'www.invicta-group.co.uk',
#  'Być może miało',
#  'Assurance vieAssurance',
#  'Caixa Económica Montepio Geral',
#  'UsStanton',
#  'communs aux secteurs de la banque et de l’assuranceDocuments de nature',
#  'Na przykład',
#  'Niemcy',
#  'zum Schutz',
#  'Zugang auf',
#  'werden auf Grundlage von Art',
#  'et séminaires de rechercheConférences et séminaires de rechercheSéminaire mensuel de la Chaire ACPR «',
#  'y otros reales decretos en materia de mercado de valores',
#  'Cryptocurrency?What',
#  'aprobado por cualquier afiliado de Invest And',
#  '▌ Octanox',
#  'des pertes assurées et de nombreuses arnaques',
#  'the Grenadines\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n',
#  'że jest',
#  'Fondslösungen für Investments',
#  'четырех программ',
#  'Netherlands Authority',
#  '@CNMV_IFI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n',
#  'wyraźnie uzgodniono',
#  'który wzbudza zaufanie',
#  'Financial Markets\n\n      Authority',
#  'appareils nomadesQue faut-il savoir sur l’assurance de téléphone portable',
#  'futuros o fuera de la bolsa en moneda extranjera',
#  'U nas są',
#  'Oü',
#  'mercati finanziari',
#  'United Commonwealth Financial Protection Board',
#  'nur mit Ihrer',
#  'Pruebalo ahora\n\n\n\nPruebalo',
#  'Simple500 / Turbo Trading Ltd',
#  'Gdańsk Północ',
#  'Stocks & Shares',
#  'Przejdź',
#  'the Electronic Money Regulations 2011',
#  'Platforma inwestycyjna Trade',
#  'Polskiego RadiaNewseria',
#  'улучшение структуры',
#  'KRS 629979',
#  'ahora\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n',
#  'Relatórios',
#  'reprezentuje ją na zewnątrz',
#  'la exclusiva de un revolucionario chip de...            \n\n\n\n\n                                                        ',
#  'muy satisfecho con 24invest',
#  'Wikifin\n\n\n\nInscrivez-vous ici pour',
#  'especializado',
#  'Obsolete',
#  'EMI',
#  'Marom Partners Limited',
#  'incluindo o',
#  'Los usuarios',
#  'Gráficos',
#  'jednak Premia',
#  'beste Lösung zu erreichen',
#  'Recommendations and Opinions',
#  'the Moscow Exchange',
#  'los mercados financieros',
#  'TOGETHER!GoCloseWITHDRAWALS TERMSWhen',
#  'k.',
#  'First Capital Finance Limited',
#  'b’mod qarrieqi',
#  'że praca w InstaForex',
#  'Global Markets',
#  'CloseRisk',
#  'Collège de supervisionLe',
#  'Zilton Capital',
#  'LTV',
#  'ou entités',
#  'incluso il mercato Forex).L’avviso dato potrebbe non contenere tutte',
#  'Novak',
#  'the Vanuatu Securities and Exchange Commission',
#  'Visionner \n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n                Communiqué de presse              \n\n\n              ',
#  '★ Reviews\n\n\n\n',
#  'de Estabilidad',
#  'Dominion Financial Assets',
#  'którzy tworzą najbardziej komfortowe warunki',
#  'Wenn Sie einen',
#  'de la Directiva',
#  'necesita ser un',
#  'the Canadian Securities Administrators’',
#  'Fühlen Sie sich durch',
#  'PenaltiesEvents',
#  'Dziękuję',
#  'EC',
#  'vous prémunir des arnaques',
#  'Lp - Brock Holdings - Comtrade',
#  'Meinefund',
#  'Fragen zum Fall',
#  'Szybkie otwarcie konta',
#  'Hasta un máximo de seis miembros de tu familia podrán usar',
#  'Mitchell',
#  'https://unitex-capital.com',
#  'cuyo único objetivo es asegurarse de que tu experiencia en',
#  'Die von Ihnen',
#  'Keith Allan',
#  'Comisión Nacional de Mercado de Valores\r\n                    \n\n\n\n\n',
#  'U żadnego brokera',
#  'Business Choice Partners Group',
#  'operaciones abiertas',
#  'że fundusze',
#  'ésta Nueva Plataforma',
#  'Banco Atlântico Europa',
#  'Der Meldeprozess',
#  'Max',
#  'auch dann',
#  'Los objetivos de esta reforma',
#  'de Quantfury permite',
#  'Bright Finance',
#  'oddycha',
#  'Olympus Markets',
#  'Allen',
#  'D. Sergio Gómez Fernández',
#  '»Chaire ACPR',
#  'BankingPrivacy',
#  'Yvonne\n\n\nGreat',
#  'nebo si',
#  'Btccoinex',
#  'umów zawartych',
#  'Commonwealth of Dominica',
#  'Dunhill Wealth Advisory',
#  'identifizieren können',
#  'szybka realizacja transakcji',
#  'ou NFC',
#  'the Federal Administrative Court',
#  'Sl',
#  'zasługujący na odpowiednie oceny',
#  'IPI CAPITAL S.A.',
#  'Zhong Yang Securities',
#  'AG',
#  'Plataforma1',
#  'niezależnie od',
#  "préparer à s'assurerQue faut-il savoir avant de souscrire un contrat d'assurance",
#  'AAPL',
#  'KRS 293707',
#  'JavaScript          ',
#  "de l'article L511-41",
#  'Pracownik naukowy',
#  'Vision Introducer Ltd /',
#  'warunki handlowe firmy',
#  'Midas Wealth Management Securities',
#  'ale także',
#  'który zostanie ograniczony',
#  'Vertragsabschluss erforderlich',
#  'Wypłata\n\n\n\n\n\n\n\n\n\nZaloguj się\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n',
#  'Verarbeitung zu gewährleisten',
#  'Esempio',
#  'de mejor ejecución de MiFID II',
#  'Todo lo que necesita para tomar mejores',
#  'Empieza',
#  'nazwa',
#  'Je découvre\n\n\n\n\n\n',
#  'AstraZeneca',
#  'de Entidades',
#  'KRS 406590',
#  'wytycznymi lub inną wiadomością',
#  'Dinengo Partners Ltd',
#  'Mistertrader',
#  'lockdown',
#  'Shareholders & Service',
#  'Maklera',
#  'Vip Businesses',
#  '如何判断工装检具尺寸是否符合要求',
#  "Rapports d'activité\n",
#  'FacebookUtwórz kontoAby udostępnić',
#  'GoogleSign inGoogle',
#  'nos dirigíamos',
#  'analizar el tráfico del sitio',
#  'aby przeczytać informacje o',
#  'este sitio',
#  'OPPORTUNITYAccelerating GrowthThe',
#  'Altyx Financial Planning Ltd',
#  'Quantum Trading Indicators',
#  'Fast Loan',
#  'Account Comparision\nPayment Methods\n\n\nInstruments',
#  'Ostatecznym',
#  'na żądanie',
#  'au contrôle bancaireEntités',
#  '$18428/11/2020EOS/ETHJamie W.',
#  'est chargée',
#  'schützt unser Hinweisgebersystem auch bei',
#  'Support\n\n\n\n    \n',
#  'Direction\n\n\n\n\xa0\xa0\n',
#  'w przeciwnych kierunkach w',
#  'Ag - Global Financial Credit - Technische Isolierung Schweiz',
#  'Crypto\nExchange',
#  'że nikt',
#  'Zabawy muzyczne dla dzieci',
#  'muy bien las monedas de las acciones',
#  'Malta Financial Services Oversight Newsletter',
#  'los riesgos relacionados directamente con sus actividades comerciales',
#  'Ministerstvo',
#  'Cel',
#  'NederlandsNL',
#  'stronęRzeczpospolitaJedynka - Program',
#  'Chrome',
#  'entre otras',
#  'Backtesting',
#  'Fragen zum Thema',
#  'Índices de referencia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n            Términos más buscados',
#  'Asesorar 31/01/2019',
#  'il vous est possible',
#  'Wywiad\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n',
#  'dla takich',
#  'aby pomóc początkującym traderom',
#  'NSSC',
#  'Politicas',
#  'Unternehmen und',
#  'https://elitetrading.co',
#  'abis',
#  'Chris Sheldrick',
#  'Legal & General Assurance Society Limited',
#  'w której',
#  'au portail',
#  'różnych centrów dealerskich',
#  'Universal Leasing Limited',
#  'der Impressumspflicht',
#  'nauczyłem się przewidywać',
#  'Laino Group Limited / Exchange Cloud',
#  '☑ Global',
#  'Fiat',
#  'Klient musi zdeponować dodatkowe środki natychmiast na',
#  'opłaty oraz może',
#  'Adaptée à votre rythme',
#  'Erweiterung',
#  'que reúnen estas cualidades',
#  'Innovative Securities Limited',
#  'Dawn',
#  'Postkastens',
#  'La Comisión Nacional del Mercado de Valores',
#  'TntKids.com$6,095            ',
#  'JMS Bonds / JMSchaar Bonds',
#  'Odstupování od smluv',
#  'Warszawa-Ochota',
#  'cas de renflouement interne',
#  'Phones',
#  'Clients',
#  'Uksavingssociety.com',
#  'będą uważane za prawdziwe',
#  'nell’ora seguente',
#  'South Bay Holdings Ltd',
#  'BRITISH COLUMBIA SECURITIES COMMISSION',
#  'Incapsula',
#  'FxLinked Ltd',
#  'in")Fonds de résolution financés par les contributions des établissementsFonds de résolution utilisés pour soutenir les actions de résolutionCoopérer avec les autorités étrangèresWorking Paper',
#  'Cryptoassets',
#  'Solutions CM Ltd',
#  'Rejoignez',
#  'на правах партнера\n\n\n',
#  'カリビアンコム プレミアム 123114_062',
#  'Sony',
#  'Spółka ma prawo zamknąć niektóre lub wszystkie otwarte',
#  'TOPINVEST Renata Kaczmarek',
#  'und wird beim Schließen des Browsers',
#  'investigación y desarrollo',
#  'Agencias de calificación crediticia',
#  'The Financial Ombudsman Service',
#  'Kronos Invest/KronosInvest',
#  'English14',
#  'Falls Sie bereits',
#  '光滑环塞规点击查看详情',
#  'Schoeller Holdings',
#  'Marketsprofit.com / Profit Market Trading',
#  'the Faster Payments',
#  'OUVRIR UN',
#  'Biuro Maklerskie Alior Bank SA',
#  'Jana Matejki',
#  'Schloss-Strasse',
#  'waqqaf kull tranżazzjoni ma’ din l-entita’',
#  'LV Grow Markets',
#  'kontraktów CFD na akcje amerykańskie\n\n\n\n',
#  'FranceFirma z branży mediów',
#  'SCI - Sociedade de Consultoria',
#  'Guarantor Loans / Guarantorloansuk Ltd',
#  'Oferty',
#  'GBP/USD',
#  'Venta de Pascua',
#  'Das sind vor allem technische Daten',
#  'Vincent',
#  'leva e',
#  'argent doit',
#  ...}
